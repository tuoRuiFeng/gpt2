# %%
# !python main.py
# Out:
# Hello world!
# Epoch: 100%|████████████████████████████████████| 30/30 [43:12<00:00, 86.42s/it]
# 训练结束

# %%
# !python infer.py
# Out:
# 生成结果：
# GPT-2 is a transformers model pretrained on a very large corpus of English data , which is the " , and " . According to the Slysserologist a " <unk> , the name 's Temple of the lead that the " <unk> , a " latter " , " , standing " Black similar as "
# --------------------------------------------------

# %%
# !python infer.py
# Out:
# 生成结果：
# what can I say that the tallest movement that had a marked the shot largely " various alone . This best in this marriage , a castle is a corresponding , while they has would be a <unk> of that does a main cast like an controversial camps , writing for probably
# --------------------------------------------------

# %%
# !python infer.py
# Out:
# 生成结果：
# Beijing University of Posts and Telecommunications is an excellent university, and I were found in a batsides . This is a letter in the Roman language of the cathedral . The world was typically a <unk> , in the new <unk> , and was considered for <unk> . Recordingman of the <unk>
# --------------------------------------------------

# %%
# !python infer.py
# Out:
# 生成结果：
# Edward rose early on the New-year morning. He looked in every room and wished a busyokiceogna , again with the original solo series . After the " " live song " ( " ) , " I were a new texture @-@ true " , " Trials and " and " <unk> " . According to <
# --------------------------------------------------
